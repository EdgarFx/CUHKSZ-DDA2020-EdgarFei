# %%
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
import pydotplus
import matplotlib.pyplot as plt
import random

# %%
class DecisionTree(object):
    def __init__(self,dataframe):
        self.model = None
        self.dataframe = dataframe
        self.X_train = None
        self.Y_train = None 
        self.Y_train_pred = None
        self.X_test = None
        self.Y_test = None
        self.Y_test_pred = None
        self.mse_train = None
        self.mse_test = None
        self.max_depth = None
        self.min_node_size = None
        self.processing()
    
    def processing(self):
        self.dataframe["Urban"] = self.dataframe["Urban"].replace("No",0)
        self.dataframe["Urban"] = self.dataframe["Urban"].replace("Yes",1)
        self.dataframe["US"] = self.dataframe["US"].replace("No",0)
        self.dataframe["US"] = self.dataframe["US"].replace("Yes",1)
        self.dataframe = self.dataframe.join(pd.get_dummies(self.dataframe.ShelveLoc))
        self.dataframe = self.dataframe.drop(columns=['ShelveLoc'])
        self.Y_train = self.dataframe.iloc[:300,0].values
        self.Y_test = self.dataframe.iloc[301:,0].values
        self.X_train = self.dataframe.iloc[:300,1:].values
        self.X_test = self.dataframe.iloc[301:,1:].values
        
    def fit_dt(self,max_depth=None,min_node_size=2):
        model = tree.DecisionTreeRegressor(max_depth=max_depth,min_samples_leaf=min_node_size,random_state=0)
        model.fit(self.X_train,self.Y_train)
        self.Y_test_pred = model.predict(self.X_test)
        self.Y_train_pred = model.predict(self.X_train)
        self.mse_train = mean_squared_error(self.Y_train,self.Y_train_pred)
        self.mse_test = mean_squared_error(self.Y_test,self.Y_test_pred)
        self.model = model
        self.max_depth = max_depth
        self.min_node_size = min_node_size
        
    def fit_bagging(self,number_of_trees,max_depth=None,min_node_size=2):
        model = RandomForestRegressor(max_depth=max_depth,min_samples_leaf=min_node_size,random_state=0,n_estimators=number_of_trees,max_features=None,bootstrap=True)
        model.fit(self.X_train,self.Y_train)
        self.Y_test_pred = model.predict(self.X_test)
        self.Y_train_pred = model.predict(self.X_train)
        self.mse_train = mean_squared_error(self.Y_train,self.Y_train_pred)
        self.mse_test = mean_squared_error(self.Y_test,self.Y_test_pred)
        self.model = model
        self.max_depth = max_depth
        self.min_node_size = min_node_size
        
    def fit_random_forests(self,m,number_of_trees,max_depth=None,min_node_size=2):
        model = RandomForestRegressor(max_depth=max_depth,min_samples_leaf=min_node_size,random_state=0,n_estimators=number_of_trees,max_features=m,bootstrap=True)
        model.fit(self.X_train,self.Y_train)
        self.Y_test_pred = model.predict(self.X_test)
        self.Y_train_pred = model.predict(self.X_train)
        self.mse_train = mean_squared_error(self.Y_train,self.Y_train_pred)
        self.mse_test = mean_squared_error(self.Y_test,self.Y_test_pred)
        self.model = model
        self.max_depth = max_depth
        self.min_node_size = min_node_size
        
    def plot_tree(self):
        dot_data = tree.export_graphviz(self.model, out_file=None, 
                         feature_names=self.dataframe.columns.values.tolist()[1:],  
                         class_names=self.dataframe.columns.values.tolist()[0],  
                         filled=True, rounded=True,  
                         special_characters=True)  
        graph = pydotplus.graph_from_dot_data(dot_data)
        graph.write_pdf("tree_%s_%s.pdf"%(str(self.max_depth),str(self.min_node_size)))
        
    def bias_variance_analysis(self,max_depth=None,min_node_size=2):
        X_dataset = []
        Y_dataset = []
        index_list = [i for i in range(0,300)]
        for i in range(10):
            random.shuffle(index_list)
            X_dataset.append([self.X_train[j] for j in index_list[:200]])
            Y_dataset.append([self.Y_train[j] for j in index_list[:200]])
        number_of_trees = [i for i in range(10,301,10)]
        bias_2_list = []
        variance_list = []
        for num in range(len(number_of_trees)):
            model_Y_pred = []
            for i in range(10):
                model = RandomForestRegressor(max_depth=max_depth,min_samples_leaf=min_node_size,random_state=0,n_estimators=number_of_trees[num],max_features=None,bootstrap=True)
                model.fit(X_dataset[i],Y_dataset[i])
                model_Y_pred.append(model.predict(self.X_test))
            h_bar = sum(model_Y_pred)/10
            bias_2 = np.sum((h_bar-self.Y_test)**2)/100
            bias_2_list.append(bias_2)
            dataset_var = []
            for Y in model_Y_pred:
                D_var = np.sum((Y-h_bar)**2)/100
                dataset_var.append(D_var)
            var = sum(dataset_var)/10
            variance_list.append(var)
        plt.plot(number_of_trees,bias_2_list)
        plt.xlabel('Numbers of trees')
        plt.ylabel('Bias^2')
        plt.title('m = None,max_depth = 15,least_node_size = 5')
        plt.show()
        plt.plot(number_of_trees,variance_list)
        plt.xlabel('Numbers of trees')
        plt.ylabel('Variance')
        plt.title('m = None,max_depth = 15,least_node_size = 5')
        plt.show()

# %%
df = pd.read_csv("Carseats.csv")

# %%
def data_statistics(df):
    target = df.iloc[:,0].values
    features = np.transpose(df.iloc[:,1:].values)
    plt.hist(target,bins=20)
    plt.xlabel('Sales')
    plt.ylabel('frequency')
    plt.show()
    for i in range(10):
        plt.hist(features[i],bins=20)
        if i == 0:
            plt.xlabel('CompPrice')
        if i == 1:
            plt.xlabel('Income')
        if i == 2:
            plt.xlabel('Advertising')
        if i == 3:
            plt.xlabel('Population')
        if i == 4:
            plt.xlabel('Price')
        if i == 5:
            plt.xlabel('ShelveLoc')
        if i == 6:
            plt.xlabel('Age')
        if i == 7:
            plt.xlabel('Education')
        if i == 8:
            plt.xlabel('Urban')
        if i == 9:
            plt.xlabel('US')
        plt.ylabel('frequency')
        plt.show()

# %%
data_statistics(df)

# %%
dt = DecisionTree(df)

# %%
for i in [3,4,5]:
    for j in [10,15,20]:
        dt.fit_dt(i,j)
        dt.plot_tree()
        print("Maximum depth=%d;Least node sizes=%d: train error=%f"%(i,j,dt.mse_train))
        print("Maximum depth=%d;Least node sizes=%d: test error=%f"%(i,j,dt.mse_test))
# Out:
# Maximum depth=3;Least node sizes=10: train error=3.836145
# Maximum depth=3;Least node sizes=10: test error=5.733106
# Maximum depth=3;Least node sizes=15: train error=3.836145
# Maximum depth=3;Least node sizes=15: test error=5.733106
# Maximum depth=3;Least node sizes=20: train error=3.836145
# Maximum depth=3;Least node sizes=20: test error=5.733106
# Maximum depth=4;Least node sizes=10: train error=2.839000
# Maximum depth=4;Least node sizes=10: test error=5.478089
# Maximum depth=4;Least node sizes=15: train error=2.923774
# Maximum depth=4;Least node sizes=15: test error=5.586207
# Maximum depth=4;Least node sizes=20: train error=2.962080
# Maximum depth=4;Least node sizes=20: test error=5.573405
# Maximum depth=5;Least node sizes=10: train error=2.188816
# Maximum depth=5;Least node sizes=10: test error=5.107328
# Maximum depth=5;Least node sizes=15: train error=2.299963
# Maximum depth=5;Least node sizes=15: test error=5.343143
# Maximum depth=5;Least node sizes=20: train error=2.395884
# Maximum depth=5;Least node sizes=20: test error=5.361536

# %%
for i in [10,30,50,70,90,110,130,150]:
    for j in [5,6,7]:
        dt.fit_bagging(i,j)
        print("Number of trees=%d;Maximum depth=%d: train error=%f"%(i,j,dt.mse_train))
        print("Number of trees=%d;Maximum depth=%d: test error=%f"%(i,j,dt.mse_test))
# Out:
# Number of trees=10;Maximum depth=5: train error=1.523709
# Number of trees=10;Maximum depth=5: test error=3.798539
# Number of trees=10;Maximum depth=6: train error=1.063652
# Number of trees=10;Maximum depth=6: test error=3.550936
# Number of trees=10;Maximum depth=7: train error=0.855170
# Number of trees=10;Maximum depth=7: test error=3.381302
# Number of trees=30;Maximum depth=5: train error=1.410979
# Number of trees=30;Maximum depth=5: test error=3.218992
# Number of trees=30;Maximum depth=6: train error=0.947264
# Number of trees=30;Maximum depth=6: test error=3.121041
# Number of trees=30;Maximum depth=7: train error=0.679738
# Number of trees=30;Maximum depth=7: test error=3.016918
# Number of trees=50;Maximum depth=5: train error=1.379272
# Number of trees=50;Maximum depth=5: test error=3.174015
# Number of trees=50;Maximum depth=6: train error=0.920546
# Number of trees=50;Maximum depth=6: test error=3.029528
# Number of trees=50;Maximum depth=7: train error=0.647198
# Number of trees=50;Maximum depth=7: test error=2.928908
# Number of trees=70;Maximum depth=5: train error=1.367589
# Number of trees=70;Maximum depth=5: test error=3.072104
# Number of trees=70;Maximum depth=6: train error=0.912821
# Number of trees=70;Maximum depth=6: test error=2.938414
# Number of trees=70;Maximum depth=7: train error=0.643818
# Number of trees=70;Maximum depth=7: test error=2.877721
# Number of trees=90;Maximum depth=5: train error=1.388213
# Number of trees=90;Maximum depth=5: test error=3.050796
# Number of trees=90;Maximum depth=6: train error=0.930411
# Number of trees=90;Maximum depth=6: test error=2.885688
# Number of trees=90;Maximum depth=7: train error=0.661612
# Number of trees=90;Maximum depth=7: test error=2.835194
# Number of trees=110;Maximum depth=5: train error=1.388960
# Number of trees=110;Maximum depth=5: test error=3.059588
# Number of trees=110;Maximum depth=6: train error=0.928810
# Number of trees=110;Maximum depth=6: test error=2.893719
# Number of trees=110;Maximum depth=7: train error=0.660902
# Number of trees=110;Maximum depth=7: test error=2.824242
# Number of trees=130;Maximum depth=5: train error=1.390852
# Number of trees=130;Maximum depth=5: test error=3.057787
# Number of trees=130;Maximum depth=6: train error=0.929076
# Number of trees=130;Maximum depth=6: test error=2.915377
# Number of trees=130;Maximum depth=7: train error=0.658888
# Number of trees=130;Maximum depth=7: test error=2.850663
# Number of trees=150;Maximum depth=5: train error=1.383205
# Number of trees=150;Maximum depth=5: test error=3.033774
# Number of trees=150;Maximum depth=6: train error=0.921689
# Number of trees=150;Maximum depth=6: test error=2.904304
# Number of trees=150;Maximum depth=7: train error=0.653600
# Number of trees=150;Maximum depth=7: test error=2.846943

# %%
for i in [3,4,5]:
    for j in [10,30,50,70,90,110,130,150]:
        dt.fit_random_forests(i,j)
        print("Max features=%d;Number of trees=%d: train error=%f"%(i,j,dt.mse_train))
        print("Max features=%d;Number of trees=%d: test error=%f"%(i,j,dt.mse_test))
# Out:
# Max features=3;Number of trees=10: train error=0.609761
# Max features=3;Number of trees=10: test error=3.527889
# Max features=3;Number of trees=30: train error=0.427075
# Max features=3;Number of trees=30: test error=2.898065
# Max features=3;Number of trees=50: train error=0.392067
# Max features=3;Number of trees=50: test error=2.882067
# Max features=3;Number of trees=70: train error=0.397239
# Max features=3;Number of trees=70: test error=2.790413
# Max features=3;Number of trees=90: train error=0.404971
# Max features=3;Number of trees=90: test error=2.778243
# Max features=3;Number of trees=110: train error=0.404652
# Max features=3;Number of trees=110: test error=2.758092
# Max features=3;Number of trees=130: train error=0.405496
# Max features=3;Number of trees=130: test error=2.725680
# Max features=3;Number of trees=150: train error=0.395990
# Max features=3;Number of trees=150: test error=2.727205
# Max features=4;Number of trees=10: train error=0.577890
# Max features=4;Number of trees=10: test error=2.785994
# Max features=4;Number of trees=30: train error=0.416263
# Max features=4;Number of trees=30: test error=2.636480
# Max features=4;Number of trees=50: train error=0.392902
# Max features=4;Number of trees=50: test error=2.615278
# Max features=4;Number of trees=70: train error=0.384867
# Max features=4;Number of trees=70: test error=2.691147
# Max features=4;Number of trees=90: train error=0.393607
# Max features=4;Number of trees=90: test error=2.677629
# Max features=4;Number of trees=110: train error=0.382836
# Max features=4;Number of trees=110: test error=2.688485
# Max features=4;Number of trees=130: train error=0.382543
# Max features=4;Number of trees=130: test error=2.665488
# Max features=4;Number of trees=150: train error=0.377552
# Max features=4;Number of trees=150: test error=2.626937
# Max features=5;Number of trees=10: train error=0.567888
# Max features=5;Number of trees=10: test error=3.338159
# Max features=5;Number of trees=30: train error=0.416851
# Max features=5;Number of trees=30: test error=2.864084
# Max features=5;Number of trees=50: train error=0.373456
# Max features=5;Number of trees=50: test error=2.766778
# Max features=5;Number of trees=70: train error=0.360475
# Max features=5;Number of trees=70: test error=2.820210
# Max features=5;Number of trees=90: train error=0.363771
# Max features=5;Number of trees=90: test error=2.774381
# Max features=5;Number of trees=110: train error=0.367001
# Max features=5;Number of trees=110: test error=2.761146
# Max features=5;Number of trees=130: train error=0.368004
# Max features=5;Number of trees=130: test error=2.757214
# Max features=5;Number of trees=150: train error=0.369221
# Max features=5;Number of trees=150: test error=2.722875

# %%
dt.bias_variance_analysis(15,5)
